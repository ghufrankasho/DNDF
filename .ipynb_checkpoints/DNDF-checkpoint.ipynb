# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import numpy as np
import pandas as pd
 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
 
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
import keras
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('Dataset.csv')
df_copy = df.copy()
# df['Y'] = df['Y'].sort_values(ignore_index=True)
 
df_copy = df.copy()
df_copy['Y'].replace('a', 1, inplace=True)
df_copy['Y'].replace('b', 0, inplace=True)
# Split data into inputs (X) and output (y)
X = df_copy.iloc[:50000, 0:12]  
y = df_copy.iloc[:50000, 12:13] .astype(int)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
 

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_resampled)
X_test = scaler.transform(X_test)

# %%
# Predict
count_1=0
count_0=0
 
for index,d  in y_test.iterrows(): 
   
    
    if(d[0]==0):
        count_0 +=1
    else :count_1 +=1
    
print("count_0=",count_0,"count_1=",count_1)
# Out:
# count_0= 2043 count_1= 12957

# %%
from sklearn.utils.class_weight import compute_class_weight
y_tra=[]
for i ,row in y_test.iterrows():
    
     y_tra.append(row[0])
     
print(len(y_tra))
weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_tra),
                                        y = y_tra                                                  
                                    )
# print(weights)
class_weights = dict(enumerate(weights))
class_weights
# Out:
# 15000
# {0: 3.671071953010279, 1: 0.5788376939106274}

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import numpy as np

# Define the SoftDecisionTree class
@tf.keras.utils.register_keras_serializable()
class SoftDecisionTree(tf.keras.layers.Layer):
    def __init__(self, depth, num_features, num_classes, l2_reg=0.001, **kwargs):
        super(SoftDecisionTree, self).__init__( **kwargs)
        self.depth = depth
        self.num_features = num_features
        self.num_classes = num_classes
        self.l2_reg = l2_reg
        self.num_nodes = 2 ** (depth + 1) - 1
        self.num_leaf_nodes = 2 ** depth

        self.decision_weights = self.add_weight(
            shape=(self.num_nodes, num_features),
            initializer='random_normal',
            trainable=True,
            regularizer=l2(l2_reg)
        )

      
        self.leaf_weights = self.add_weight(
            shape=(self.num_leaf_nodes, num_classes),
            initializer='random_normal',
            trainable=True,
            regularizer=l2(l2_reg)
        )

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        path_probabilities = tf.ones((batch_size, 1))

        decision_weights_slice = self.decision_weights[0:1, :]
        decisions = tf.nn.sigmoid(tf.matmul(inputs, decision_weights_slice, transpose_b=True))

        for d in range(1, self.depth + 1):
            path_prob_left = path_probabilities * decisions
            path_prob_right = path_probabilities * (1 - decisions)
            path_probabilities = tf.concat([path_prob_left, path_prob_right], axis=1)

            start_index = 2 ** d - 1
            end_index = 2 ** (d + 1) - 1
            decision_weights_slice = self.decision_weights[start_index:end_index, :]
            decisions = tf.nn.sigmoid(tf.matmul(inputs, decision_weights_slice, transpose_b=True))
        
        leaf_probabilities = tf.nn.sigmoid(tf.matmul(path_probabilities, self.leaf_weights))
   
        return leaf_probabilities
    def get_config(self):
        config = super(SoftDecisionTree, self).get_config()
        config.update({
            'depth': self.depth,
            'num_features': self.num_features,
            'num_classes': self.num_classes,
            'trainable': self.trainable,
        })
        return config



tf.keras.utils.get_custom_objects()['SoftDecisionTree'] = SoftDecisionTree

# %%
batch_size = tf.shape(X_train)
batch_size
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([60682,    12])>

# %%
# Define the DNDF model
def create_dndf_model(num_trees, depth, num_features, num_classes):
    inputs = Input(shape=(num_features,))
    trees = [SoftDecisionTree(depth, num_features, num_classes) for _ in range(num_trees)]
    tree_outputs = [tree(inputs) for tree in trees]
   
    concatenated_outputs = Concatenate()(tree_outputs)
    outputs = Dense(num_classes, activation='sigmoid')(concatenated_outputs)  # Use sigmoid for binary classification
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Parameters
num_trees = 10
depth = 4  # Depth of each decision tree
num_features = X_train.shape[1]
num_classes = 1  # Binary classification (sigmoid output)

# Create DNDF model
dndf_model = create_dndf_model(num_trees, depth, num_features, num_classes)

# Callbacks
initial_learning_rate = 0.0001
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
# Adjust learning rate
initial_learning_rate = 0.0001
dndf_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Parameters
num_trees = 10
depth = 4 # Depth of each decision tree
num_features = X_train.shape[1]
num_classes = 1  # Binary classification (sigmoid output)

# Create DNDF model
dndf_model = create_dndf_model(num_trees, depth, num_features, num_classes)

# Callbacks
initial_learning_rate = 0.0001
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
# Adjust learning rate
initial_learning_rate = 0.0001
dndf_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])
 

# Train the model
history=dndf_model.fit(X_train, y_resampled, epochs=100, batch_size=32, validation_data=(X_test, y_test),  callbacks=[reduce_lr,early_stopping])

# Evaluate the model
loss, accuracy = dndf_model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# Epoch 1/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 33s 7ms/step - accuracy: 0.4988 - loss: 0.7119 - val_accuracy: 0.1362 - val_loss: 0.7058 - learning_rate: 1.0000e-04
# Epoch 2/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4999 - loss: 0.6936 - val_accuracy: 0.1362 - val_loss: 0.6963 - learning_rate: 1.0000e-04
# Epoch 3/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5108 - loss: 0.6934 - val_accuracy: 0.1362 - val_loss: 0.6966 - learning_rate: 1.0000e-04
# Epoch 4/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5089 - loss: 0.6932 - val_accuracy: 0.8638 - val_loss: 0.6912 - learning_rate: 1.0000e-04
# Epoch 5/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5433 - loss: 0.6931 - val_accuracy: 0.8638 - val_loss: 0.6916 - learning_rate: 1.0000e-04
# Epoch 6/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5367 - loss: 0.6930 - val_accuracy: 0.9187 - val_loss: 0.6922 - learning_rate: 1.0000e-04
# Epoch 7/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5855 - loss: 0.6928 - val_accuracy: 0.5589 - val_loss: 0.6937 - learning_rate: 1.0000e-04
# Epoch 8/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6940 - loss: 0.6925 - val_accuracy: 0.9045 - val_loss: 0.6918 - learning_rate: 1.0000e-04
# Epoch 9/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7527 - loss: 0.6920 - val_accuracy: 0.5634 - val_loss: 0.6946 - learning_rate: 1.0000e-04
# Epoch 10/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6374 - loss: 0.6912 - val_accuracy: 0.8638 - val_loss: 0.6799 - learning_rate: 1.0000e-04
# Epoch 11/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7107 - loss: 0.6902 - val_accuracy: 0.8677 - val_loss: 0.6887 - learning_rate: 1.0000e-04
# Epoch 12/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8945 - loss: 0.6886 - val_accuracy: 0.9729 - val_loss: 0.6805 - learning_rate: 1.0000e-04
# Epoch 13/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8966 - loss: 0.6861 - val_accuracy: 0.8694 - val_loss: 0.6828 - learning_rate: 1.0000e-04
# Epoch 14/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9381 - loss: 0.6825 - val_accuracy: 0.9247 - val_loss: 0.6725 - learning_rate: 1.0000e-04
# Epoch 15/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9524 - loss: 0.6769 - val_accuracy: 0.9017 - val_loss: 0.6657 - learning_rate: 1.0000e-04
# Epoch 16/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9459 - loss: 0.6690 - val_accuracy: 0.8981 - val_loss: 0.6542 - learning_rate: 1.0000e-04
# Epoch 17/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9435 - loss: 0.6579 - val_accuracy: 0.9077 - val_loss: 0.6360 - learning_rate: 1.0000e-04
# Epoch 18/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9359 - loss: 0.6429 - val_accuracy: 0.9091 - val_loss: 0.6152 - learning_rate: 1.0000e-04
# Epoch 19/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9375 - loss: 0.6241 - val_accuracy: 0.8937 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 20/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9353 - loss: 0.6022 - val_accuracy: 0.8763 - val_loss: 0.5823 - learning_rate: 1.0000e-04
# Epoch 21/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9301 - loss: 0.5789 - val_accuracy: 0.8835 - val_loss: 0.5544 - learning_rate: 1.0000e-04
# Epoch 22/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9341 - loss: 0.5526 - val_accuracy: 0.8829 - val_loss: 0.5304 - learning_rate: 1.0000e-04
# Epoch 23/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9337 - loss: 0.5264 - val_accuracy: 0.8857 - val_loss: 0.5053 - learning_rate: 1.0000e-04
# Epoch 24/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9349 - loss: 0.4998 - val_accuracy: 0.8921 - val_loss: 0.4772 - learning_rate: 1.0000e-04
# Epoch 25/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9381 - loss: 0.4727 - val_accuracy: 0.8949 - val_loss: 0.4541 - learning_rate: 1.0000e-04
# Epoch 26/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9386 - loss: 0.4493 - val_accuracy: 0.8959 - val_loss: 0.4349 - learning_rate: 1.0000e-04
# Epoch 27/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9401 - loss: 0.4266 - val_accuracy: 0.9011 - val_loss: 0.4124 - learning_rate: 1.0000e-04
# Epoch 28/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9412 - loss: 0.4059 - val_accuracy: 0.9021 - val_loss: 0.3969 - learning_rate: 1.0000e-04
# Epoch 29/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9452 - loss: 0.3850 - val_accuracy: 0.9063 - val_loss: 0.3799 - learning_rate: 1.0000e-04
# Epoch 30/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9464 - loss: 0.3684 - val_accuracy: 0.9115 - val_loss: 0.3636 - learning_rate: 1.0000e-04
# Epoch 31/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9475 - loss: 0.3549 - val_accuracy: 0.9157 - val_loss: 0.3492 - learning_rate: 1.0000e-04
# Epoch 32/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9499 - loss: 0.3413 - val_accuracy: 0.9155 - val_loss: 0.3419 - learning_rate: 1.0000e-04
# Epoch 33/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9517 - loss: 0.3292 - val_accuracy: 0.9198 - val_loss: 0.3302 - learning_rate: 1.0000e-04
# Epoch 34/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9509 - loss: 0.3217 - val_accuracy: 0.9209 - val_loss: 0.3234 - learning_rate: 1.0000e-04
# Epoch 35/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9521 - loss: 0.3120 - val_accuracy: 0.9213 - val_loss: 0.3173 - learning_rate: 1.0000e-04
# Epoch 36/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9516 - loss: 0.3073 - val_accuracy: 0.9241 - val_loss: 0.3093 - learning_rate: 1.0000e-04
# Epoch 37/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9555 - loss: 0.2964 - val_accuracy: 0.9257 - val_loss: 0.3026 - learning_rate: 1.0000e-04
# Epoch 38/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9566 - loss: 0.2915 - val_accuracy: 0.9254 - val_loss: 0.3001 - learning_rate: 1.0000e-04
# Epoch 39/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9561 - loss: 0.2864 - val_accuracy: 0.9287 - val_loss: 0.2930 - learning_rate: 1.0000e-04
# Epoch 40/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9567 - loss: 0.2823 - val_accuracy: 0.9299 - val_loss: 0.2883 - learning_rate: 1.0000e-04
# Epoch 41/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9564 - loss: 0.2787 - val_accuracy: 0.9303 - val_loss: 0.2852 - learning_rate: 1.0000e-04
# Epoch 42/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9573 - loss: 0.2740 - val_accuracy: 0.9323 - val_loss: 0.2803 - learning_rate: 1.0000e-04
# Epoch 43/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9568 - loss: 0.2702 - val_accuracy: 0.9328 - val_loss: 0.2777 - learning_rate: 1.0000e-04
# Epoch 44/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9579 - loss: 0.2662 - val_accuracy: 0.9322 - val_loss: 0.2764 - learning_rate: 1.0000e-04
# Epoch 45/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9594 - loss: 0.2613 - val_accuracy: 0.9337 - val_loss: 0.2725 - learning_rate: 1.0000e-04
# Epoch 46/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9580 - loss: 0.2613 - val_accuracy: 0.9349 - val_loss: 0.2694 - learning_rate: 1.0000e-04
# Epoch 47/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9584 - loss: 0.2587 - val_accuracy: 0.9350 - val_loss: 0.2674 - learning_rate: 1.0000e-04
# Epoch 48/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9598 - loss: 0.2551 - val_accuracy: 0.9332 - val_loss: 0.2678 - learning_rate: 1.0000e-04
# Epoch 49/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9591 - loss: 0.2535 - val_accuracy: 0.9367 - val_loss: 0.2617 - learning_rate: 1.0000e-04
# Epoch 50/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9604 - loss: 0.2491 - val_accuracy: 0.9362 - val_loss: 0.2614 - learning_rate: 1.0000e-04
# Epoch 51/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9585 - loss: 0.2503 - val_accuracy: 0.9329 - val_loss: 0.2637 - learning_rate: 1.0000e-04
# Epoch 52/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9599 - loss: 0.2459 - val_accuracy: 0.9367 - val_loss: 0.2579 - learning_rate: 1.0000e-04
# Epoch 53/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9609 - loss: 0.2433 - val_accuracy: 0.9364 - val_loss: 0.2569 - learning_rate: 1.0000e-04
# Epoch 54/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9592 - loss: 0.2449 - val_accuracy: 0.9372 - val_loss: 0.2541 - learning_rate: 1.0000e-04
# Epoch 55/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9596 - loss: 0.2417 - val_accuracy: 0.9383 - val_loss: 0.2517 - learning_rate: 1.0000e-04
# Epoch 56/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9591 - loss: 0.2412 - val_accuracy: 0.9367 - val_loss: 0.2529 - learning_rate: 1.0000e-04
# Epoch 57/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9605 - loss: 0.2381 - val_accuracy: 0.9381 - val_loss: 0.2500 - learning_rate: 1.0000e-04
# Epoch 58/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9616 - loss: 0.2356 - val_accuracy: 0.9383 - val_loss: 0.2486 - learning_rate: 1.0000e-04
# Epoch 59/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9609 - loss: 0.2356 - val_accuracy: 0.9378 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 60/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9614 - loss: 0.2340 - val_accuracy: 0.9413 - val_loss: 0.2422 - learning_rate: 1.0000e-04
# Epoch 61/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9614 - loss: 0.2316 - val_accuracy: 0.9412 - val_loss: 0.2413 - learning_rate: 1.0000e-04
# Epoch 62/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9614 - loss: 0.2312 - val_accuracy: 0.9404 - val_loss: 0.2417 - learning_rate: 1.0000e-04
# Epoch 63/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9615 - loss: 0.2306 - val_accuracy: 0.9375 - val_loss: 0.2446 - learning_rate: 1.0000e-04
# Epoch 64/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9607 - loss: 0.2296 - val_accuracy: 0.9399 - val_loss: 0.2408 - learning_rate: 1.0000e-04
# Epoch 65/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9615 - loss: 0.2266 - val_accuracy: 0.9416 - val_loss: 0.2373 - learning_rate: 1.0000e-04
# Epoch 66/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9605 - loss: 0.2285 - val_accuracy: 0.9397 - val_loss: 0.2392 - learning_rate: 1.0000e-04
# Epoch 67/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9603 - loss: 0.2274 - val_accuracy: 0.9387 - val_loss: 0.2401 - learning_rate: 1.0000e-04
# Epoch 68/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9607 - loss: 0.2262 - val_accuracy: 0.9387 - val_loss: 0.2392 - learning_rate: 1.0000e-04
# Epoch 69/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9617 - loss: 0.2232 - val_accuracy: 0.9383 - val_loss: 0.2388 - learning_rate: 1.0000e-04
# Epoch 70/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9609 - loss: 0.2239 - val_accuracy: 0.9419 - val_loss: 0.2331 - learning_rate: 1.0000e-04
# Epoch 71/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9615 - loss: 0.2218 - val_accuracy: 0.9417 - val_loss: 0.2323 - learning_rate: 1.0000e-04
# Epoch 72/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9616 - loss: 0.2211 - val_accuracy: 0.9404 - val_loss: 0.2335 - learning_rate: 1.0000e-04
# Epoch 73/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9610 - loss: 0.2206 - val_accuracy: 0.9395 - val_loss: 0.2341 - learning_rate: 1.0000e-04
# Epoch 74/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9632 - loss: 0.2174 - val_accuracy: 0.9431 - val_loss: 0.2285 - learning_rate: 1.0000e-04
# Epoch 75/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9626 - loss: 0.2181 - val_accuracy: 0.9403 - val_loss: 0.2316 - learning_rate: 1.0000e-04
# Epoch 76/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9616 - loss: 0.2181 - val_accuracy: 0.9387 - val_loss: 0.2336 - learning_rate: 1.0000e-04
# Epoch 77/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9610 - loss: 0.2165 - val_accuracy: 0.9418 - val_loss: 0.2282 - learning_rate: 1.0000e-04
# Epoch 78/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9629 - loss: 0.2159 - val_accuracy: 0.9419 - val_loss: 0.2273 - learning_rate: 1.0000e-04
# Epoch 79/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9622 - loss: 0.2151 - val_accuracy: 0.9399 - val_loss: 0.2296 - learning_rate: 1.0000e-04
# Epoch 80/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9624 - loss: 0.2151 - val_accuracy: 0.9421 - val_loss: 0.2259 - learning_rate: 1.0000e-04
# Epoch 81/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9636 - loss: 0.2121 - val_accuracy: 0.9417 - val_loss: 0.2260 - learning_rate: 1.0000e-04
# Epoch 82/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9625 - loss: 0.2116 - val_accuracy: 0.9408 - val_loss: 0.2267 - learning_rate: 1.0000e-04
# Epoch 83/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9621 - loss: 0.2123 - val_accuracy: 0.9434 - val_loss: 0.2223 - learning_rate: 1.0000e-04
# Epoch 84/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9616 - loss: 0.2125 - val_accuracy: 0.9405 - val_loss: 0.2259 - learning_rate: 1.0000e-04
# Epoch 85/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9626 - loss: 0.2104 - val_accuracy: 0.9423 - val_loss: 0.2222 - learning_rate: 1.0000e-04
# Epoch 86/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9627 - loss: 0.2099 - val_accuracy: 0.9409 - val_loss: 0.2239 - learning_rate: 1.0000e-04
# Epoch 87/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9628 - loss: 0.2087 - val_accuracy: 0.9419 - val_loss: 0.2224 - learning_rate: 1.0000e-04
# Epoch 88/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9603 - loss: 0.2101 - val_accuracy: 0.9419 - val_loss: 0.2216 - learning_rate: 1.0000e-04
# Epoch 89/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9615 - loss: 0.2095 - val_accuracy: 0.9419 - val_loss: 0.2212 - learning_rate: 1.0000e-04
# Epoch 90/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9645 - loss: 0.2050 - val_accuracy: 0.9429 - val_loss: 0.2186 - learning_rate: 1.0000e-04
# Epoch 91/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9631 - loss: 0.2056 - val_accuracy: 0.9435 - val_loss: 0.2175 - learning_rate: 1.0000e-04
# Epoch 92/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9630 - loss: 0.2063 - val_accuracy: 0.9428 - val_loss: 0.2181 - learning_rate: 1.0000e-04
# Epoch 93/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9627 - loss: 0.2058 - val_accuracy: 0.9448 - val_loss: 0.2139 - learning_rate: 1.0000e-04
# Epoch 94/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9635 - loss: 0.2042 - val_accuracy: 0.9407 - val_loss: 0.2204 - learning_rate: 1.0000e-04
# Epoch 95/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9620 - loss: 0.2043 - val_accuracy: 0.9425 - val_loss: 0.2170 - learning_rate: 1.0000e-04
# Epoch 96/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9636 - loss: 0.2032 - val_accuracy: 0.9417 - val_loss: 0.2179 - learning_rate: 1.0000e-04
# Epoch 97/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9622 - loss: 0.2057 - val_accuracy: 0.9414 - val_loss: 0.2177 - learning_rate: 1.0000e-04
# Epoch 98/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9613 - loss: 0.2036 - val_accuracy: 0.9413 - val_loss: 0.2175 - learning_rate: 1.0000e-04
# Epoch 99/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9621 - loss: 0.2028 - val_accuracy: 0.9439 - val_loss: 0.2131 - learning_rate: 1.0000e-04
# Epoch 100/100
# 1897/1897 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9622 - loss: 0.2017 - val_accuracy: 0.9419 - val_loss: 0.2154 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 99.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9449 - loss: 0.2138
# Test Loss: 0.21305429935455322, Test Accuracy: 0.9438666701316833

# %%
model = keras.models.save_model(dndf_model,'DNDF.keras')

# %%
# Load the model
custom_objects = {'SoftDecisionTree': SoftDecisionTree}
loaded_model = tf.keras.models.load_model('DNDF.keras', custom_objects=custom_objects)

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Function to plot a decision tree
def plot_tree(decision_probabilities, depth):
    G = nx.DiGraph()
    pos = {}
    labels = {}

    # Helper function to add nodes and edges to the graph
    def add_node_edges(node, probability, level):
        if level > depth:
            return

        node_id = f"{node}-{level}"
        G.add_node(node_id)
        pos[node_id] = (level, -node)
        labels[node_id] = f"{probability:.2f}"

        if level < depth:
            left_child = node * 2
            right_child = node * 2 + 1
            G.add_edge(node_id, f"{left_child}-{level + 1}")
            G.add_edge(node_id, f"{right_child}-{level + 1}")
            left_prob = decision_probabilities[left_child - 1]
            right_prob = decision_probabilities[right_child - 1]
            add_node_edges(left_child, left_prob, level + 1)
            add_node_edges(right_child, right_prob, level + 1)

    # Start with the root node
    add_node_edges(1, decision_probabilities[0], 1)

    # Draw the graph
    plt.figure(figsize=(12, 8))
    nx.draw(G, pos, labels=labels, with_labels=True, node_size=3000, node_color='skyblue', font_size=10)
    plt.show()

# Function to get decision probabilities for a random input
def get_decision_probabilities(model, input_data, tree_index=0):
    inputs = tf.convert_to_tensor(input_data, dtype=tf.float32)
    tree_layer = model.layers[4 + tree_index]  # SoftDecisionTree layer index in the model
    batch_size = tf.shape(inputs)[0]

    decision_weights = tree_layer.decision_weights.numpy()
    path_probabilities = tf.ones((batch_size, 1), dtype=tf.float32)

    probabilities = []

    decision_weights_slice = decision_weights[0:1, :]
    decisions = tf.nn.sigmoid(tf.matmul(inputs, decision_weights_slice, transpose_b=True))
    probabilities.append(decisions.numpy()[0, 0])

    for d in range(1, tree_layer.depth + 1):
        path_prob_left = path_probabilities * tf.cast(decisions, tf.float32)
        path_prob_right = path_probabilities * (1 - tf.cast(decisions, tf.float32))
        path_probabilities = tf.concat([path_prob_left, path_prob_right], axis=1)

        start_index = 2 ** d - 1
        end_index = 2 ** (d + 1) - 1
        decision_weights_slice = decision_weights[start_index:end_index, :]
        decisions = tf.nn.sigmoid(tf.matmul(inputs, decision_weights_slice, transpose_b=True))

        for decision in decisions.numpy()[0]:
            probabilities.append(decision)

    return probabilities




# Example input (one sample from your dataset)
random_input = X_test[0:1]  # Take a single sample from your test data

# Get decision probabilities for the first tree
decision_probabilities = get_decision_probabilities(dndf_model, random_input, tree_index=2)

# Plot the tree
plot_tree(decision_probabilities, depth)

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Predict the labels for the test set
y_pred = dndf_model.predict(X)
y_pred = (y_pred > 0.90).astype(int)  # Round predictions to the nearest integer (binary classification)
# Compute the confusion matrix
cm = confusion_matrix(y, y_pred)
# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])  # Adjust labels as needed
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')

plt.show()
loss, accuracy = dndf_model.evaluate(X, y)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5728 - loss: 3.2417
# Test Loss: 3.1086275577545166, Test Accuracy: 0.5909090638160706

# %%
df = pd.read_csv('old_Dataset.csv')
df_copy = df.copy()
# df['Y'] = df['Y'].sort_values(ignore_index=True)
 
df_copy = df.copy()
df_copy['Y'].replace('a', 1, inplace=True)
df_copy['Y'].replace('b', 0, inplace=True)
# Split data into inputs (X) and output (y)
X = df_copy.iloc[:88, 0:12]  
y = df_copy.iloc[:88, 12:13] .astype(int)
